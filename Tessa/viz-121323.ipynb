# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

# import functions from file in parent folder
import sys
sys.path.append('../')
from viz import plot_symp_group_freq
# reload file import
import importlib
importlib.reload(sys.modules['viz'])
# Out:
# <module 'viz' from '../viz.py'>

# %%
clus= pd.read_csv("../clusterings/tessa/cluster_13_111023.csv", index_col=0)

# %%
clus
# Out:
#        cluster
# 3            8
# 5           11
# 6           10
# 8            0
# 9           10
# ...        ...
# 14158        2
# 14161       11
# 14163        6
# 14166        8
# 14168       11
#
# [6031 rows x 1 columns]

# %%
symp_groups = pd.read_csv("../clusterings/tessa/symptom_groups.csv", index_col=0)

# %%
plot_symp_group_freq(clus, include_misc=False)
# Out:
# /Users/tessa/Documents/GitHub/PLR/Tessa/../viz.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #sympdf['cluster'] = clusters['cluster']
#            Memory  Cognitive    Speech  Auditory  Headaches  Olfaction  \
# cluster
# 0        0.281098   0.362652  0.013338  0.120596   0.301982   0.222942
# 1        0.602247   0.737640  0.591292  0.669164   0.694382   0.551264
# 2        0.507769   0.618546  0.485902  0.304651   0.401003   0.236529
# 3        0.202186   0.042987  0.014117  0.108075   0.145173   0.135018
# 4        0.207712   0.048329  0.013496  0.027421   0.050129   0.157134
# 5        0.314773   0.363068  0.184659  0.214015   0.273011   0.195668
# 6        0.410690   0.555902  0.371659  0.280376   0.370824   0.281459
# ...

# %%
# clus_chris = pd.read_csv('../clusterings/chris/parametric_umap_n_clusters_7.csv', index_col=0)
clus_chris = pd.read_csv('../clusterings/chris/umap_kmeans_ensemble_up_to_40_components_inclusion_any_n_cluster_8.csv', index_col=0)
avdf = plot_symp_group_freq(clus_chris, include_misc=False)
# Out:
# ../viz.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sympdf['cluster'] = clusters.iloc[:,-1]

# %%
norm = avdf.div(avdf.sum(axis=1), axis='rows')

# %%
norm
# Out:
#            Memory  Cognitive    Speech  Auditory  Headaches  Olfaction  \
# cluster
# 0        0.062822   0.080144  0.038183  0.036930   0.056868   0.036014
# 1        0.083184   0.066853  0.023666  0.032470   0.049764   0.052006
# 2        0.052115   0.067635  0.049104  0.050804   0.058197   0.041763
#
#          Gastrointenstinal   Sensory     Motor     Sleep    Vision  \
# cluster
# 0                 0.069581  0.045231  0.052029  0.074273  0.036245
# 1                 0.070257  0.044964  0.050110  0.072750  0.031228
# 2                 0.067501  0.053162  0.055520  0.064021  0.050050
#
#          Temperature   Cardiac  Respiratory  Allergic  Genitourinary  \
# cluster
# 0           0.076069  0.090202     0.079786  0.030923       0.017302
# 1           0.067075  0.090689     0.092768  0.035056       0.018671
# 2           0.068953  0.071287     0.059283  0.041510       0.022171
#
#              Skin  Musculoskeletal
# cluster
# 0        0.028208         0.089189
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(norm.transpose(), cmap='RdBu_r', center=0)
