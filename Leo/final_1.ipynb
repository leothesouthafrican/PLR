# %%
import pandas as pd
# Custom Helper Functions
from helper_functions import print_boxed_text, save_boxed_text_to_file, phi_coefficient, one_hot_encode, standardize_numeric

# %%
dataset_1 = pd.read_csv("/Users/leo/Programming/PLR/Leo/data/dataset_1.csv").drop(columns=["Unnamed: 0"])

# %%
#Drop skewed features
def drop_skewed_features(df, threshold=0.5):
    """
    Drop features that are skewed towards 0 or 1.
    
    Parameters:
        df (DataFrame): The input DataFrame with binary features.
        threshold (float): The skewness threshold. Features with skewness above this value will be dropped.
        
    Returns:
        DataFrame: A new DataFrame with skewed features removed.
    """
    lines = ["Dropped Skewed Features"]
    is_title = [True]
    
    dropped_features = []
    
    for col in df.columns:
        # Calculate the skewness for each feature
        skewness = df[col].mean()
        
        # Check if the feature is skewed towards 0 or 1
        if skewness > threshold or skewness < (1 - threshold):
            line = f"Dropping {col} with skewness {skewness:.4f}"
            lines.append(line)
            is_title.append(False)
            dropped_features.append(col)
            
    # Drop the skewed features
    df_dropped = df.drop(columns=dropped_features)
    
    print_boxed_text(lines, is_title)
    
    return df_dropped


threshold = 0.75  #Setting this to a very conservative 95% threshold would be good to discuss this as a team
dataset_4_unskewed = drop_skewed_features(dataset_4, threshold)
# Out:
# ┌────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                        Dropped Skewed Features                                         │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                                                                                        │
# │ Dropping Symptom_Memory_short with skewness 0.9242                                                     │
# │ Dropping Symptom_Memory_no_new_memories with skewness 0.0875                                           │
# │ Dropping Symptom_Memory_forget_tasks with skewness 0.1380                                              │
# │ Dropping Symptom_Memory_other with skewness 0.1200                                                     │
# │ Dropping Symptom_Cognitive_Functioning_fastthoughts with skewness 0.1733                               │
# │ Dropping Symptom_Cognitive_Functioning_agnosia with skewness 0.1083                                    │
# │ Dropping Symptom_Cognitive_Functioning_attentionconcentration with skewness 0.7529                     │
# │ Dropping Symptom_Cognitive_Functioning_other with skewness 0.0871                                      │
# │ Dropping Symptom_Speech_difficulty_speaking_complete_sentences with skewness 0.2341                    │
# │ Dropping Symptom_Speech_speaking_unrecognizable_words with skewness 0.0947                             │
# │ Dropping Symptom_Speech_difficulty_communicating_writing with skewness 0.1673                          │
# │ Dropping Symptom_Speech_changes_to_secondary_languages with skewness 0.0557                            │
# │ Dropping Symptom_Speech_other with skewness 0.0431                                                     │
# │ Dropping Symptom_Headaches_migraines with skewness 0.2414                                              │
# │ Dropping Symptom_Headaches_other with skewness 0.1333                                                  │
# │ Dropping Symptom_Headaches_brain_warmth with skewness 0.1205                                           │
# │ Dropping Symptom_Phantom_smell with skewness 0.2489                                                    │
# │ Dropping Symptom_Altered_smell with skewness 0.2268                                                    │
# │ Dropping Symptom_Phantom_taste with skewness 0.0990                                                    │
# │ Dropping Symptom_Heightened_smell with skewness 0.0822                                                 │
# │ Dropping Symptom_Heightened_taste with skewness 0.0308                                                 │
# │ Dropping Symptom_Nightmares with skewness 0.2413                                                       │
# │ Dropping Symptom_Restless_leg with skewness 0.1899                                                     │
# │ Dropping Symptom_Lucid_dreams with skewness 0.1567                                                     │
# │ Dropping Symptom_Sleep_apnea with skewness 0.1262                                                      │
# │ Dropping Symptom_Waking_up_early with skewness 0.2462                                                  │
# │ Dropping Symptom_Hallucinations_visual with skewness 0.1033                                            │
# │ Dropping Symptom_Hallucinations_auditory with skewness 0.0711                                          │
# │ Dropping Symptom_Hallucinations_tactile with skewness 0.0337                                           │
# │ Dropping Symptom_Hallucinations_other with skewness 0.0234                                             │
# │ Dropping Symptom_Sensations_numbness_one_sided_weakness with skewness 0.1282                           │
# │ Dropping Symptom_Sensations_facial_pressure_left with skewness 0.0793                                  │
# │ Dropping Symptom_Sensations_facial_pressure_right with skewness 0.0680                                 │
# │ Dropping Symptom_Sensations_facial_pressure_other with skewness 0.0602                                 │
# │ Dropping Symptom_Sensations_facial_paralysis with skewness 0.0320                                      │
# │ Dropping Symptom_Low_temp with skewness 0.1942                                                         │
# │ Dropping Symptom_Bradycardia with skewness 0.1643                                                      │
# │ Dropping Symptom_Bulging_veins with skewness 0.1648                                                    │
# │ Dropping Symptom_Fainting with skewness 0.1277                                                         │
# │ Dropping Symptom_New_anaphylaxis with skewness 0.0429                                                  │
# │ Dropping Symptom_Acute_confusion with skewness 0.1935                                                  │
# │ Dropping Symptom_Slurring_words with skewness 0.1670                                                   │
# │ Dropping Symptom_Vomiting with skewness 0.1499                                                         │
# │ Dropping Symptom_Coughing_up_blood with skewness 0.0479                                                │
# │ Dropping Symptom_Rattling_breath with skewness 0.1749                                                  │
# │ Dropping Symptom_Respiratory_other with skewness 0.0861                                                │
# │ Dropping Symptom_Hearing_loss with skewness 0.0970                                                     │
# │ Dropping Symptom_Reproductive_all_menstrual_issues with skewness 0.1836                                │
# │ Dropping Symptom_Bladder_control with skewness 0.1569                                                  │
# │ Dropping Symptom_Peeling_skin with skewness 0.1260                                                     │
# │ Dropping Symptom_Petechiae with skewness 0.1632                                                        │
# │ Dropping Symptom_Covid_toes with skewness 0.1290                                                       │
# │ Dropping Symptom_Dermatographia with skewness 0.0804                                                   │
# │ Dropping Symptom_Skin_Allergy_other with skewness 0.0947                                               │
# │ Dropping Symptom_Inability_to_yawn with skewness 0.0541                                                │
# │ Dropping Symptom_Ear_ear_pain with skewness 0.2469                                                     │
# │ Dropping Symptom_Ear_changes_to_ear_canal with skewness 0.2156                                         │
# │ Dropping Symptom_Ear_numbness with skewness 0.0494                                                     │
# │ Dropping Symptom_Other_ear_hearing_symptoms with skewness 0.2074                                       │
# │ Dropping Symptom_Eye_Vision_floaters with skewness 0.2039                                              │
# │ Dropping Symptom_Eye_Vision_double_vision with skewness 0.0796                                         │
# │ Dropping Symptom_Eye_Vision_tunnel_vision with skewness 0.0383                                         │
# │ Dropping Symptom_Eye_Vision_loss_of_vision with skewness 0.0111                                        │
# │ Dropping Symptom_Eye_Vision_pink_eye with skewness 0.1270                                              │
# │ Dropping Symptom_Eye_Vision_bloodshot_eyes with skewness 0.1411                                        │
# │ Dropping Symptom_Eye_Vision_redness_outside_eye with skewness 0.0832                                   │
# │ Dropping Symptom_Eye_Vision_seeing_things_peripheral_vision with skewness 0.1336                       │
# │ Dropping Symptom_Reproductive_early_menopause with skewness 0.0139                                     │
# │ Dropping Symptom_Reproductive_abnormally_heavy_periods_clotting with skewness 0.0953                   │
# │ Dropping Symptom_Reproductive_testicle_penis_pain_changes with skewness 0.0365                         │
# │ Dropping Symptom_Reproductive_sexual_dysfunction with skewness 0.1129                                  │
# │ Dropping Symptom_Reproductive_postmenopausal_bleeding with skewness 0.0161                             │
# │ Dropping Symptom_Reproductive_other_urinary_issues with skewness 0.1535                                │
# │ Dropping Symptom_Reproductive_other_menstrual_issues with skewness 0.0900                              │
# │ Dropping Symptom_Reproductive_abnormally_irregular_periods with skewness 0.1207                        │
# │ Dropping Symptom_Gastrointestinal_hyperactive_bowel with skewness 0.2386                               │
# │ Dropping Symptom_SkinAllergy_itchy_eyes with skewness 0.2451                                           │
# │ Dropping Symptom_SkinAllergy_heighted_reaction_allergies with skewness 0.1239                          │
# │ Dropping Symptom_SkinAllergy_brittle_nail with skewness 0.1094                                         │
# │ Dropping Symptom_SkinAllergy_other_itchy with skewness 0.0574                                          │
# │ Dropping Symptom_SkinAllergy_shingles with skewness 0.0257                                             │
# │ Dropping Symptom_Change_sensitivity_to_meds with skewness 0.2089                                       │
# │ Dropping Symptom_New_allergies with skewness 0.1111                                                    │
# │ Dropping FAS_cat_Substantial Fatigue with skewness 0.1829                                              │
# │ Dropping HasPeriods_0 with skewness 0.2228                                                             │
# │ Dropping HasPeriods_No, other reason with skewness 0.1013                                              │
# │ Dropping HasPeriods_No, post-menopausal with skewness 0.2323                                           │
# │ Dropping Demographics_Ancestry_Cleaned_0 with skewness 0.0041                                          │
# │ Dropping Demographics_Ancestry_Cleaned_Asian, South Asian, South East Asian with skewness 0.0284       │
# │ Dropping Demographics_Ancestry_Cleaned_Black with skewness 0.0176                                      │
# │ Dropping Demographics_Ancestry_Cleaned_Hispanic, Latino, or Spanish Origin with skewness 0.0279        │
# │ Dropping Demographics_Ancestry_Cleaned_Multiple ancestries, including white with skewness 0.0590       │
# │ Dropping Demographics_Ancestry_Cleaned_Multiple ancestries, not including white with skewness 0.0095   │
# │ Dropping Demographics_Ancestry_Cleaned_Other with skewness 0.0194                                      │
# │ Dropping Demographics_Ancestry_Cleaned_White with skewness 0.8342                                      │
# │ Dropping Demographics_Gender_Cleaned_0 with skewness 0.0038                                            │
# │ Dropping Demographics_Gender_Cleaned_Man with skewness 0.1998                                          │
# │ Dropping Demographics_Gender_Cleaned_Non-binary/Genderqueer/Gender non-conforming with skewness 0.0166 │
# │ Dropping Demographics_Gender_Cleaned_Woman with skewness 0.7798                                        │
# │ Dropping Demographics_Trans_Cleaned_0.0 with skewness 0.9838                                           │
# │ Dropping Demographics_Trans_Cleaned_1.0 with skewness 0.0162                                           │
# │ Dropping Demographics_Age_Cleaned_18-29 with skewness 0.0872                                           │
# │ Dropping Demographics_Age_Cleaned_30-39 with skewness 0.2242                                           │
# │ Dropping Demographics_Age_Cleaned_50-59 with skewness 0.2421                                           │
# │ Dropping Demographics_Age_Cleaned_60-69 with skewness 0.1220                                           │
# │ Dropping Demographics_Age_Cleaned_70-79 with skewness 0.0353                                           │
# │ Dropping Demographics_Age_Cleaned_80+ with skewness 0.0032                                             │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Initialize an empty dataframe to store phi values
phi_values = pd.DataFrame(index=dataset_4_unskewed.columns, columns=dataset_4_unskewed.columns)

# Calculate phi values
for col1 in dataset_4_unskewed.columns:
    for col2 in dataset_4_unskewed.columns:
        contingency_table = pd.crosstab(dataset_4_unskewed[col1], dataset_4_unskewed[col2])
        phi = phi_coefficient(contingency_table)
        phi_values.loc[col1, col2] = phi

# Convert to float
phi_values = phi_values.astype(float)

threshold = 0.4  # I decided to set this to 0.5 just based off what feels right, would be interesting to get some clinical input on this.
to_drop = []

for col1 in dataset_4_unskewed.columns:
    for col2 in dataset_4_unskewed.columns:
        if col1 >= col2:  # This ensures each pair is only considered once
            continue
        if (col1 in phi_values.index) and (col2 in phi_values.columns):
            phi_value = abs(phi_values.loc[col1, col2])
            if phi_value > threshold:
                to_drop.append((col1, col2, phi_value))

# Sort the list so that the same columns are dropped each time
to_drop.sort(key=lambda x: x[2], reverse=True)  # Sort by phi_value

dropped_columns = set()
lines = ["Dropped Columns and Their Phi Coefficients"]
is_title = [True]
for col1, col2, phi_value in to_drop:
    if col1 not in dropped_columns and col2 not in dropped_columns:
        lines.append(f"Dropping column '{col1}' which has a phi coefficient of {phi_value} with '{col2}'")
        is_title.append(False)
        dropped_columns.add(col1)
print_boxed_text(lines, is_title)

dataset_4_drop_corr = dataset_4_unskewed.drop(columns=dropped_columns)
# Out:
# ┌────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                                                     Dropped Columns and Their Phi Coefficients                                                                     │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                                                                                                                                                                    │
# │ Dropping column 'Cognitive_PEM_Severity' which has a phi coefficient of 0.7457924263674615 with 'Physical_PEM_Severity'                                                            │
# │ Dropping column 'Symptom_Loss_of_smell' which has a phi coefficient of 0.7203605016489107 with 'Symptom_Loss_of_taste'                                                             │
# │ Dropping column 'Symptom_Eye_Vision_blurred_vision' which has a phi coefficient of 0.6833805018994307 with 'Symptom_Eye_vision_symptoms'                                           │
# │ Dropping column 'FAS' which has a phi coefficient of 0.6708203932499369 with 'Symptom_Sensations_numbness_loss_sensation'                                                          │
# │ Dropping column 'FAS_cat_Fatigue' which has a phi coefficient of 0.6639092536841917 with 'FAS_cat_Minimal/No Fatigue'                                                              │
# │ Dropping column 'Symptom_Speech_difficulty_communicating_verbally' which has a phi coefficient of 0.645792884463965 with 'Symptom_Speech_difficulty_finding_words'                 │
# │ Dropping column 'Symptom_Insomnia' which has a phi coefficient of 0.643378191317829 with 'Symptom_Waking_up_in_night'                                                              │
# │ Dropping column 'Symptom_Speech_difficulty_reading_processing_text' which has a phi coefficient of 0.5984073345578579 with 'Symptom_Speech_difficulty_understanding_others_speech' │
# │ Dropping column 'Symptom_Cognitive_Functioning_executive' which has a phi coefficient of 0.5845863096182017 with 'Symptom_Cognitive_Functioning_problemsolving'                    │
# │ Dropping column 'Symptom_Speech_difficulty_finding_words' which has a phi coefficient of 0.5800036138873319 with 'Symptom_Speech_difficulty_understanding_others_speech'           │
# │ Dropping column 'Symptom_Elevated_temp' which has a phi coefficient of 0.5406671376621606 with 'Symptom_Temp_lability'                                                             │
# │ Dropping column 'Symptom_Cognitive_Functioning_problemsolving' which has a phi coefficient of 0.5125885604004632 with 'Symptom_Cognitive_Functioning_thinking'                     │
# │ Dropping column 'Symptom_Tremors' which has a phi coefficient of 0.4918862952016915 with 'Symptom_Vibrating_sensations'                                                            │
# │ Dropping column 'Symptom_Runny_nose' which has a phi coefficient of 0.48809229228481843 with 'Symptom_Sneezing'                                                                    │
# │ Dropping column 'Symptom_Difficulty_falling_asleep' which has a phi coefficient of 0.4742278667967224 with 'Symptom_Waking_up_in_night'                                            │
# │ Dropping column 'Symptom_Gasping_air_normal_oxygen' which has a phi coefficient of 0.46851172845340366 with 'Symptom_Shortness_of_breath'                                          │
# │ Dropping column 'Symptom_Sensations_skin_burning_no_rash' which has a phi coefficient of 0.4418992792316982 with 'Symptom_Sensations_tingling_prickling'                           │
# │ Dropping column 'Symptom_Joint_pain' which has a phi coefficient of 0.4414686571620175 with 'Symptom_Muscle_aches'                                                                 │
# │ Dropping column 'Symptom_Pain_burning_chest' which has a phi coefficient of 0.4330672141113255 with 'Symptom_Tightness_of_chest'                                                   │
# │ Dropping column 'Symptom_Heart_palpitations' which has a phi coefficient of 0.43283224722001706 with 'Symptom_Tachycardia'                                                         │
# │ Dropping column 'Symptom_Ear_sensitivity_to_noise' which has a phi coefficient of 0.42755644995288006 with 'Symptom_Eye_Vision_sensitivity_to_light'                               │
# │ Dropping column 'Symptom_Sensations_numbness_loss_sensation' which has a phi coefficient of 0.41562052388447784 with 'Symptom_Sensations_tingling_prickling'                       │
# │ Dropping column 'Symptom_Headaches_base_of_skull' which has a phi coefficient of 0.41045951267973596 with 'Symptom_Headaches_stiff_neck'                                           │
# │ Dropping column 'Symptom_Shortness_of_breath' which has a phi coefficient of 0.40479583685906384 with 'Symptom_Tightness_of_chest'                                                 │
# │ Dropping column 'Symptom_SkinAllergy_itchy_skin' which has a phi coefficient of 0.400746778471283 with 'Symptom_Skin_rashes'                                                       │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
import numpy as np
import umap
import hdbscan
from sklearn.metrics import silhouette_score
import itertools

# Function to perform clustering and calculate silhouette score
def cluster_and_evaluate(data, umap_params, hdbscan_params):
    umap_model = umap.UMAP(**umap_params, random_state=42)
    data_umap = umap_model.fit_transform(data)
    
    clusterer = hdbscan.HDBSCAN(**hdbscan_params)
    cluster_labels = clusterer.fit_predict(data_umap)
    
    # Check if the number of clusters is within the desired range
    n_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
    if 5 <= n_clusters <= 10:
        score = silhouette_score(data_umap, cluster_labels)
        return score, n_clusters
    else:
        return -1, n_clusters  # Invalid result due to cluster number constraints

# Define the parameter grid
umap_params = [
    {'n_neighbors': n, 'min_dist': d}
    for n in [5, 10, 15, 20]
    for d in [0.0, 0.1, 0.2, 0.3]
]

hdbscan_params = [
    {'min_cluster_size': s, 'min_samples': m}
    for s in [5, 10, 15, 20]
    for m in [1, 5, 10, 15]
]

# Grid search
best_score = -1
best_params = None
best_cluster_number = None

for umap_param_values, hdbscan_param_values in itertools.product(umap_params, hdbscan_params):
    score, n_clusters = cluster_and_evaluate(dataset_4_drop_corr, umap_param_values, hdbscan_param_values)
    print(f"Silhouette Score: {score:.4f} | Number of Clusters: {n_clusters} | UMAP Parameters: {umap_param_values} | HDBSCAN Parameters: {hdbscan_param_values}")
    if score > best_score:
        best_score = score
        best_params = (umap_param_values, hdbscan_param_values)
        best_cluster_number = n_clusters

# Output the best parameters and score
print(f"Best Silhouette Score: {best_score}")
print(f"Best UMAP Parameters: {best_params[0]}")
print(f"Best HDBSCAN Parameters: {best_params[1]}")
print(f"Number of Clusters: {best_cluster_number}")
# Out:
# /Users/leo/Programming/PLR/Leo/env/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/leo/Programming/PLR/Leo/env/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/leo/Programming/PLR/Leo/env/lib/python3.11/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/leo/Programming/PLR/Leo/env/lib/python3.11/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# Silhouette Score: -1.0000 | Number of Clusters: 485 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 255 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 111 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 75 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 235 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 159 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 87 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 68 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 151 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 105 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 67 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 56 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 114 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 71 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 53 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 48 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 519 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 17 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 221 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 114 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 84 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: 0.1154 | Number of Clusters: 10 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 143 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 83 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 67 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: 0.1321 | Number of Clusters: 9 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 111 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 69 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: 0.1271 | Number of Clusters: 9 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: 0.1425 | Number of Clusters: 7 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 540 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 28 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 227 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 117 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 22 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 18 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 91 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: 0.0650 | Number of Clusters: 10 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: 0.0902 | Number of Clusters: 7 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: 0.1041 | Number of Clusters: 7 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 515 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 244 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 120 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 222 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 149 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 80 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -0.2108 | Number of Clusters: 5 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 105 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: 0.0568 | Number of Clusters: 5 | UMAP Parameters: {'n_neighbors': 5, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 523 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 251 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 225 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 116 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 146 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 82 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 94 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: 0.2688 | Number of Clusters: 10 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 517 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 227 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 86 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 214 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 115 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 61 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 140 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 77 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 49 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 101 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 529 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 240 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 16 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 233 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 102 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 12 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 124 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 69 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -0.1532 | Number of Clusters: 9 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 86 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -0.1381 | Number of Clusters: 8 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 542 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 240 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 237 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 144 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 79 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 99 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 12 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: 0.0434 | Number of Clusters: 7 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 496 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 219 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 93 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 71 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 206 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 114 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 68 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 52 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 112 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 85 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 54 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 40 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 91 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 64 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 37 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 32 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 510 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 218 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 222 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 112 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 141 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 76 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 104 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 56 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 555 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 213 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 236 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 133 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 106 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 543 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 237 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 232 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 138 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 155 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 99 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 105 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 63 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: 0.0010 | Number of Clusters: 6 | UMAP Parameters: {'n_neighbors': 15, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 543 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 207 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 106 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 68 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 216 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 120 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 70 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 12 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 136 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 78 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 61 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -0.0679 | Number of Clusters: 8 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 98 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 59 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 13 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: 0.1011 | Number of Clusters: 7 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.0} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 507 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 242 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 107 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 24 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 240 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 131 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 77 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -0.0081 | Number of Clusters: 10 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 142 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: 0.0288 | Number of Clusters: 9 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -0.0894 | Number of Clusters: 10 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 109 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 61 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: 0.1184 | Number of Clusters: 5 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: 0.0159 | Number of Clusters: 5 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.1} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 541 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 242 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 117 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -0.0624 | Number of Clusters: 10 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 239 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 109 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 73 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: 0.0079 | Number of Clusters: 9 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 140 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 81 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: 0.0923 | Number of Clusters: 5 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 103 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 62 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 3 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: 0.0923 | Number of Clusters: 5 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.2} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 530 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 221 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 97 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 5, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 235 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 122 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 14 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 4 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 10, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 147 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 82 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 5}
# Silhouette Score: -1.0000 | Number of Clusters: 14 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 15, 'min_samples': 15}
# Silhouette Score: -1.0000 | Number of Clusters: 97 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 1}
# Silhouette Score: -1.0000 | Number of Clusters: 68 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Silhouette Score: -0.2482 | Number of Clusters: 10 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 10}
# Silhouette Score: -1.0000 | Number of Clusters: 2 | UMAP Parameters: {'n_neighbors': 20, 'min_dist': 0.3} | HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 15}
# Best Silhouette Score: 0.268801212310791
# Best UMAP Parameters: {'n_neighbors': 10, 'min_dist': 0.0}
# Best HDBSCAN Parameters: {'min_cluster_size': 20, 'min_samples': 5}
# Number of Clusters: 10

# %%
# Perform clustering with the best parameters
umap_params = best_params[0]
hdbscan_params = best_params[1]

umap_model = umap.UMAP(**umap_params, random_state=42)
dataset_4_umap = umap_model.fit_transform(dataset_4_drop_corr)

clusterer = hdbscan.HDBSCAN(**hdbscan_params)

cluster_labels = clusterer.fit_predict(dataset_4_umap)

# Visualize the clusters
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

plt.figure(figsize=(12, 8))
plt.scatter(dataset_4_umap[:, 0], dataset_4_umap[:, 1], c=cluster_labels, s=1, cmap='Spectral')
plt.title(f"UMAP Projection of the Dataset (n_clusters={best_cluster_number})")
plt.savefig("umap_projection.png", dpi=300)
plt.show()

#save to df
dataset_4_umap_df = pd.DataFrame(dataset_4_umap, columns=["UMAP1", "UMAP2"])
dataset_4_umap_df["Cluster"] = cluster_labels
dataset_4_umap_df.to_csv("dataset_4_umap.csv")

# %%
import pandas as pd

# Load the groupings
groupings_path = '/Users/leo/Programming/PLR/Leo/data/symptom_groups.csv'
symptom_groups = pd.read_csv(groupings_path)

# Create a dictionary from the symptom groups
group_dict = dict(zip(symptom_groups['symptom'], symptom_groups['group']))

def aggregate_columns(data, group_dict):
    aggregated_data = pd.DataFrame()

    # Iterate over each column in the DataFrame
    for col in data.columns:
        if col.startswith('Grouped'):
            # Keep 'Grouped' columns as they are
            aggregated_data[col] = data[col]
        elif col in group_dict:
            # Aggregate columns based on their group
            group_name = group_dict[col]
            if group_name not in aggregated_data:
                aggregated_data[group_name] = data[col]
            else:
                aggregated_data[group_name] += data[col]
        else:
            # For columns not in the group_dict, add them as is
            aggregated_data[col] = data[col]

    # Compute the average for each group
    for group in set(group_dict.values()):
        if group in aggregated_data:
            aggregated_data[group] /= len([col for col in group_dict if group_dict[col] == group])

    return aggregated_data

# Aggregate the columns
dataset_aggregated = aggregate_columns(dataset_4_drop_corr, group_dict)

dataset_aggregated
# Out:
#       Memory  Cognitive  Auditory  Headaches  Olfaction   Sensory  Sleep  \
# 0        0.0        0.2  0.000000        0.0      0.000  0.000000    0.1
# 1        0.2        0.2  0.222222        0.3      0.000  0.111111    0.2
# 2        0.0        0.2  0.000000        0.0      0.000  0.222222    0.2
# 3        0.0        0.1  0.111111        0.3      0.250  0.333333    0.3
# 4        0.0        0.1  0.111111        0.0      0.000  0.333333    0.2
# ...      ...        ...       ...        ...        ...       ...    ...
# 6026     0.2        0.2  0.222222        0.4      0.000  0.111111    0.3
# 6027     0.2        0.2  0.111111        0.0      0.000  0.111111    0.1
# 6028     0.2        0.1  0.111111        0.3      0.000  0.111111    0.3
# 6029     0.0        0.0  0.000000        0.0      0.125  0.000000    0.2
# 6030     0.2        0.2  0.111111        0.2      0.000  0.000000    0.1
#
#       Temperature  Motor  Cardiac  ...  Gastrointenstinal  Respiratory  \
# 0           0.250   0.00      0.2  ...           0.111111        0.125
# 1           0.250   0.25      0.2  ...           0.111111        0.250
# 2           0.125   0.00      0.2  ...           0.111111        0.125
# 3           0.500   0.00      0.4  ...           0.777778        0.250
# 4           0.500   0.25      0.4  ...           0.444444        0.250
# ...           ...    ...      ...  ...                ...          ...
# 6026        0.250   0.00      0.4  ...           0.222222        0.125
# 6027        0.000   0.00      0.4  ...           0.111111        0.250
# 6028        0.625   0.25      0.2  ...           0.444444        0.375
# 6029        0.000   0.00      0.0  ...           0.222222        0.000
# 6030        0.000   0.00      0.2  ...           0.333333        0.125
#
#       Allergic    Vision  Skin  Musculoskeletal  Physical_PEM_Severity  \
# 0     0.000000  0.000000  0.00             0.25                    0.5
# 1     0.000000  0.166667  0.00             0.25                    0.9
# 2     0.000000  0.000000  0.00             0.50                    0.8
# 3     0.000000  0.000000  0.00             0.50                    0.7
# 4     0.111111  0.083333  0.00             0.25                    1.0
# ...        ...       ...   ...              ...                    ...
# 6026  0.000000  0.250000  0.25             0.50                    0.8
# 6027  0.000000  0.000000  0.00             0.00                    1.0
# 6028  0.111111  0.083333  0.00             0.50                    0.8
# 6029  0.000000  0.250000  0.00             0.00                    0.0
# 6030  0.111111  0.083333  0.00             0.25                    0.9
#
#       FAS_cat_Minimal/No Fatigue  HasPeriods_Yes  \
# 0                              1               0
# 1                              0               0
# 2                              1               0
# 3                              1               1
# 4                              1               1
# ...                          ...             ...
# 6026                           0               0
# 6027                           0               0
# 6028                           0               1
# 6029                           1               0
# 6030                           0               0
#
#       Demographics_Age_Cleaned_40-49
# 0                                  0
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...
# 6026                               0
# 6027                               0
# 6028                               0
# 6029                               0
# 6030                               0
#
# [6031 rows x 21 columns]

# %%
import seaborn as sns

def plot_cluster_averages(data, cluster_labels):
    cluster_averages = pd.DataFrame()

    for label in np.unique(cluster_labels):
        if label == -1:  # Skip noise points
            continue

        cluster_data = data[data['cluster'] == label]

        # Exclude 'Grouped' columns
        filtered_data = cluster_data[[col for col in cluster_data.columns if not col.startswith('Grouped')]]

        # Exclude the 'Cluster' column
        filtered_data = filtered_data.drop('cluster', axis=1)

        cluster_avg = filtered_data.mean()
        cluster_averages[f'Cluster {label}'] = cluster_avg

    # Plotting the heatmap
    plt.figure(figsize=(len(cluster_averages.columns) * 2, len(cluster_averages.index) * 0.5))
    sns.heatmap(cluster_averages, annot=True, fmt=".2f", cmap="YlGnBu")
    plt.title("Average Feature Values per Cluster (Excluding 'Grouped')")
    plt.ylabel("Feature")
    plt.xlabel("Cluster")
    plt.show()

# Example usage of the function
plot_cluster_averages(dataset_aggregated, dataset_4_drop_corr['cluster'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Programming/PLR/Leo/env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/Programming/PLR/Leo/env/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Programming/PLR/Leo/env/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 30
#      27     plt.show()
#      29 # Example usage of the function
# ---> 30 plot_cluster_averages(dataset_aggregated, dataset_4_drop_corr['cluster'])
#
# File ~/Programming/PLR/Leo/env/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/Programming/PLR/Leo/env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'cluster'

# %%
import pandas as pd
import numpy as np

def cluster_averages_table(data, cluster_labels):
    unique_labels = np.unique(cluster_labels)
    unique_labels = unique_labels[unique_labels != -1]  # Exclude noise points

    # Prepare a DataFrame to store the averages
    cluster_averages = pd.DataFrame()

    for label in unique_labels:
        # Filter the data for each cluster
        cluster_data = data[data['cluster'] == label]

        # Filter out 'Grouped' columns and the 'cluster' column
        filtered_columns = [col for col in cluster_data.columns if not col.startswith('Grouped') and col != 'cluster']
        cluster_data = cluster_data[filtered_columns]

        # Calculate the mean and add it to the DataFrame
        cluster_avg = cluster_data.mean()
        cluster_averages[f'Cluster {label}'] = cluster_avg

    # Transpose the DataFrame for better readability
    cluster_averages = cluster_averages.transpose()

    # Optionally, sort the columns if needed
    # cluster_averages = cluster_averages.sort_values(by='some_column', ascending=False)

    return cluster_averages

# Example usage of the function
cluster_avg_table = cluster_averages_table(dataset_aggregated, dataset_4_drop_corr['cluster'])
print(cluster_avg_table)
# Out:
#                Memory  Cognitive  Auditory  Headaches  Olfaction   Sensory  \
# Cluster 0    0.152000   0.178000  0.097778   0.438000   0.072500  0.180000
# Cluster 1    0.120000   0.150000  0.111111   0.470000   0.137500  0.155556
# Cluster 2    0.007407   0.025926  0.049383   0.070370   0.046296  0.255144
# Cluster 3    0.097436   0.146154  0.074074   0.397436   0.073718  0.170940
# Cluster 4    0.111111   0.151852  0.086420   0.307407   0.055556  0.213992
# ...               ...        ...       ...        ...        ...       ...
# Cluster 107  0.043478   0.134783  0.048309   0.113043   0.054348  0.115942
# Cluster 108  0.028571   0.028571  0.010582   0.064286   0.062500  0.074074
# Cluster 109  0.000000   0.013636  0.015152   0.109091   0.056818  0.050505
# Cluster 110  0.018182   0.018182  0.010101   0.136364   0.090909  0.060606
# Cluster 111  0.009677   0.011290  0.012545   0.035484   0.024194  0.041219
#
#                 Sleep  Temperature     Motor   Cardiac  ...  \
# Cluster 0    0.260000     0.415000  0.190000  0.364000  ...
# Cluster 1    0.150000     0.225000  0.100000  0.300000  ...
# Cluster 2    0.244444     0.379630  0.129630  0.274074  ...
# Cluster 3    0.187179     0.336538  0.179487  0.323077  ...
# Cluster 4    0.262963     0.384259  0.175926  0.348148  ...
# ...               ...          ...       ...       ...  ...
# Cluster 107  0.104348     0.152174  0.130435  0.260870  ...
# Cluster 108  0.133333     0.151786  0.089286  0.204762  ...
# Cluster 109  0.095455     0.096591  0.102273  0.163636  ...
# Cluster 110  0.081818     0.204545  0.000000  0.163636  ...
# Cluster 111  0.083871     0.048387  0.012097  0.077419  ...
#
#              Gastrointenstinal  Respiratory  Allergic    Vision      Skin  \
# Cluster 0             0.300000     0.202500  0.013333  0.238333  0.110000
# Cluster 1             0.200000     0.075000  0.000000  0.258333  0.050000
# Cluster 2             0.362140     0.208333  0.020576  0.123457  0.129630
# Cluster 3             0.236467     0.173077  0.017094  0.158120  0.051282
# Cluster 4             0.502058     0.259259  0.065844  0.126543  0.046296
# ...                        ...          ...       ...       ...       ...
# Cluster 107           0.164251     0.233696  0.024155  0.072464  0.032609
# Cluster 108           0.148148     0.122024  0.021164  0.071429  0.047619
# Cluster 109           0.121212     0.045455  0.000000  0.049242  0.022727
# Cluster 110           0.202020     0.250000  0.010101  0.022727  0.000000
# Cluster 111           0.116487     0.252016  0.010753  0.044355  0.040323
#
#              Musculoskeletal  Physical_PEM_Severity  \
# Cluster 0           0.405000               0.828000
# Cluster 1           0.400000               0.680000
# Cluster 2           0.407407               0.659259
# Cluster 3           0.442308               0.871795
# Cluster 4           0.453704               0.844444
# ...                      ...                    ...
# Cluster 107         0.293478               0.669565
# Cluster 108         0.196429               0.528571
# Cluster 109         0.215909               0.472727
# Cluster 110         0.181818               0.509091
# Cluster 111         0.092742               0.419355
#
#              FAS_cat_Minimal/No Fatigue  HasPeriods_Yes  \
# Cluster 0                      0.060000        0.520000
# Cluster 1                      0.300000        0.200000
# Cluster 2                      0.518519        0.592593
# Cluster 3                      0.025641        0.589744
# Cluster 4                      0.111111        0.518519
# ...                                 ...             ...
# Cluster 107                    0.086957        0.608696
# Cluster 108                    0.380952        0.190476
# Cluster 109                    0.681818        0.000000
# Cluster 110                    0.818182        0.545455
# Cluster 111                    0.967742        0.370968
#
#              Demographics_Age_Cleaned_40-49
# Cluster 0                          0.180000
# Cluster 1                          0.400000
# Cluster 2                          0.592593
# Cluster 3                          0.179487
# Cluster 4                          0.296296
# ...                                     ...
# Cluster 107                        0.565217
# Cluster 108                        0.166667
# Cluster 109                        0.090909
# Cluster 110                        0.363636
# Cluster 111                        0.403226
#
# [112 rows x 21 columns]
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg
# /var/folders/dt/bgs1hq3d2k3dvhpt3llvs4rw0000gn/T/ipykernel_52506/995045841.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cluster_averages[f'Cluster {label}'] = cluster_avg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def plot_cluster_averages(data, cluster_labels):
    unique_labels = np.unique(cluster_labels)
    unique_labels = unique_labels[unique_labels != -1]  # Exclude noise points

    num_clusters = len(unique_labels)
    num_columns = 3  # Set the number of columns for the subplot grid
    num_rows = np.ceil(num_clusters / num_columns).astype(int)  # Calculate the number of rows needed

    plt.figure(figsize=(25, num_rows * 4))  # Adjust figure size as needed

    for i, label in enumerate(unique_labels):
        # Filter out 'Grouped' columns and the 'cluster' column
        filtered_columns = [col for col in data.columns if not col.startswith('Grouped') and col != 'cluster']
        cluster_data = data[data['cluster'] == label][filtered_columns]

        cluster_avg = cluster_data.mean().sort_values(ascending=False)
        cluster_averages = pd.DataFrame(cluster_avg).transpose()

        # Create a subplot for each cluster in a grid of num_rows x num_columns
        plt.subplot(num_rows, num_columns, i + 1)
        sns.heatmap(cluster_averages, annot=True, fmt=".2f", cmap="YlGnBu")
        plt.title(f"Cluster {label} Feature Values (Sorted)")
        plt.ylabel("Feature")
        plt.xlabel("Average Value")

    plt.tight_layout()
    plt.show()

# Example usage of the function
plot_cluster_averages(dataset_aggregated, dataset_4_drop_corr['cluster'])
