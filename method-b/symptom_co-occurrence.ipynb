# %% [markdown]
# #### Notebook to address the following two points raised by Hannah:
#
# > 1. I think it would be helpful to look at what symptoms only happen on their own (or maybe with like less than 5 others). I would guess that’s true for a % of smell and taste loss
# > 2. also, it would be interesting to see what the 3% of people without fatigue do have!
#
# #### Main takeways:
#
# - Only Symptom_Memory_short ever occurs on its own.
# - (I think) There are no symptoms which exclusively occur in a small group. But there are symptoms which tend to co-occur with a smaller number of symptoms, and those which tend to co-occur with larger number of symptoms - see 2x co-occurence distribution plots near end of notebook which illustrate the two extremes.
# - Loss of smell and taste are both on the top 30 symtpoms with the lowest minimum number of co-occurent symptoms (see dataframe head below). On average they co-occur with ~49 others symptoms, which is well below the mean of 58.6 (see first plot).
# - Patients without fatigue are 3% of the dataset - see dataframe of the end of the notebook for the 20 most and least common symptoms these patients have.
#
# This analysis can be extended if interesting...(I will in any case be creating a co-occurence network of symptoms, which will be the inverse of my patient network, and can be used to produce or evaluate symptom groupings.)

# %%
import pandas as pd
import numpy as np

from utilities import load_symptom_data

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = load_symptom_data('../data/cleaned_data_SYMPTOMS_9_13_23.csv')

# %%
row_sum = df.sum(axis=1)

# %%
shared = pd.DataFrame()

# %%
# Convert the zeros to nan, because we want zeros to indicate no shared symptoms. Whereas nan indicates symptom itself is not present for that patient.
df_nan = df[df == 0] = np.nan

# %%
shared = df.to_numpy()

# %%
for i in range(shared.shape[1]):
    shared[:, i] *= row_sum - 1

# %%
shared = pd.DataFrame(shared, columns=df.columns)

# %%
shared = shared.transpose()

# %%
shared_summary = pd.DataFrame(index = shared.index)

# %%
shared_summary['mean'] = np.nanmean(shared, axis=1)
shared_summary['median'] = np.nanmedian(shared, axis=1)
shared_summary['min'] = np.nanmin(shared, axis=1)
shared_summary['max'] = np.nanmax(shared, axis=1)
shared_summary['std'] = np.nanstd(shared, axis=1)

# %%
shared_summary.sort_values(by='min', ascending=True).head(30)
# Out:
#                                                    mean  median  min    max  \
# Symptom_Memory_short                          44.494438    42.0  0.0  154.0
# Symptom_SkinAllergy_other_itchy               58.641618    53.5  1.0  154.0
# Symptom_Fatigue                               44.546301    42.0  1.0  154.0
# Symptom_Sensations_skin_burning_no_rash       55.520305    53.0  1.0  154.0
# Symptom_Joint_pain                            52.856580    51.0  2.0  154.0
# Symptom_Vivid_dreams                          55.579845    53.0  2.0  154.0
# Symptom_Altered_smell                         54.591374    53.0  2.0  154.0
# Symptom_Sleep_other                           51.318795    49.0  2.0  154.0
# Symptom_Dry_cough                             48.065450    45.0  2.0  154.0
# Symptom_Muscle_aches                          50.140548    48.0  3.0  154.0
# Symptom_PEM                                   46.333271    44.0  3.0  154.0
# Symptom_Headaches_migraines                   57.101648    54.0  3.0  154.0
# Symptom_Tightness_of_chest                    49.035592    46.0  3.0  154.0
# Symptom_Altered_taste                         54.221628    52.0  3.0  154.0
# Symptom_Loss_of_smell                         48.519662    45.0  3.0  154.0
# Symptom_Temp_lability                         53.208661    50.0  4.0  154.0
# Symptom_Eye_Vision_sensitivity_to_light       61.003170    59.0  4.0  154.0
# Symptom_Phantom_smell                         57.586942    56.0  4.0  154.0
# Symptom_Loss_of_taste                         49.469907    46.0  4.0  154.0
# Symptom_Tremors                               55.616112    54.0  4.0  154.0
# Symptom_Sensations_electrical_zaps            60.698612    59.0  4.0  154.0
# Symptom_Sensations_tingling_prickling         53.834540    52.0  4.0  154.0
# Symptom_Night_sweats                          55.293996    53.0  4.0  154.0
# Symptom_Tinnitus                              56.572193    54.0  4.0  154.0
# Symptom_Sensations_numbness_loss_sensation    56.902059    54.0  4.0  154.0
# Symptom_Sensations_weakness                   53.411406    51.0  4.0  154.0
# Symptom_Merged_temperature_other_temp_issues  52.765479    50.0  4.0  154.0
# Symptom_Respiratory_other                     49.622351    47.0  4.0  130.0
# Symptom_Ear_sensitivity_to_noise              58.125118    56.0  4.0  154.0
# Symptom_Memory_long                           54.717652    53.0  4.0  154.0
#
#                                                     std
# Symptom_Memory_short                          22.181758
# Symptom_SkinAllergy_other_itchy               25.913683
# Symptom_Fatigue                               21.708770
# Symptom_Sensations_skin_burning_no_rash       22.130459
# Symptom_Joint_pain                            21.820781
# Symptom_Vivid_dreams                          22.351080
# Symptom_Altered_smell                         25.244775
# Symptom_Sleep_other                           21.765257
# Symptom_Dry_cough                             21.966756
# Symptom_Muscle_aches                          21.660530
# Symptom_PEM                                   21.578513
# Symptom_Headaches_migraines                   23.080231
# Symptom_Tightness_of_chest                    21.809505
# Symptom_Altered_taste                         24.408320
# Symptom_Loss_of_smell                         23.162870
# Symptom_Temp_lability                         22.467644
# Symptom_Eye_Vision_sensitivity_to_light       21.851803
# Symptom_Phantom_smell                         24.290134
# Symptom_Loss_of_taste                         23.510439
# Symptom_Tremors                               22.608131
# Symptom_Sensations_electrical_zaps            22.735099
# Symptom_Sensations_tingling_prickling         22.154269
# Symptom_Night_sweats                          22.057043
# Symptom_Tinnitus                              22.797299
# Symptom_Sensations_numbness_loss_sensation    22.666612
# Symptom_Sensations_weakness                   22.390889
# Symptom_Merged_temperature_other_temp_issues  22.274231
# Symptom_Respiratory_other                     24.257926
# Symptom_Ear_sensitivity_to_noise              22.238342
# Symptom_Memory_long                           22.269079

# %%
shared_summary['mean'].hist();
plt.axvline(shared_summary['mean'].mean(), color='k', label='distribution mean = %.2f' % shared_summary['mean'].mean());
plt.legend()
plt.title('Distribution of mean number of co-occurrent symptoms');
plt.xlabel('mean number of co-occurent symptoms')
plt.ylabel('frequency');

# %% [markdown]
# ##### Symptom_Memory_short is the only one that appears without any other symptoms. This happens for 5 patients:

# %%
shared = shared.transpose()

# %%
(shared==0).sum().sort_values(ascending=False)
# Out:
# Symptom_Memory_short                       5
# Symptom_Changes_in_voice                   0
# Symptom_Respiratory_other                  0
# Symptom_Hearing_loss                       0
# Symptom_Tinnitus                           0
#                                           ..
# Symptom_Hallucinations_auditory            0
# Symptom_Hallucinations_tactile             0
# Symptom_Hallucinations_other               0
# Symptom_Sensations_skin_burning_no_rash    0
# Symptom_New_allergies                      0
# Length: 162, dtype: int64

# %% [markdown]
# ##### Four symptoms occur just with one other:

# %%
(shared==1).sum().sort_values(ascending=False)
# Out:
# Symptom_Memory_short                          5
# Symptom_Fatigue                               2
# Symptom_Sensations_skin_burning_no_rash       2
# Symptom_SkinAllergy_other_itchy               1
# Symptom_Petechiae                             0
#                                              ..
# Symptom_Hallucinations_auditory               0
# Symptom_Hallucinations_tactile                0
# Symptom_Hallucinations_other                  0
# Symptom_Sensations_numbness_loss_sensation    0
# Symptom_New_allergies                         0
# Length: 162, dtype: int64

# %% [markdown]
# #### Most symptoms co-occur with a maximum of 154 other symptoms. However, this is just one patient with 157 symptoms:

# %%
(shared==154).sum().sort_values(ascending=False).head(15)
# Out:
# Symptom_Memory_short                         1
# Symptom_Fainting                             1
# Symptom_Sore_throat                          1
# Symptom_Hearing_loss                         1
# Symptom_Tinnitus                             1
# Symptom_Eye_vision_symptoms                  1
# Symptom_Reproductive_all_menstrual_issues    1
# Symptom_Bladder_control                      1
# Symptom_Peeling_skin                         1
# Symptom_Petechiae                            1
# Symptom_Covid_toes                           1
# Symptom_Dermatographia                       1
# Symptom_Skin_rashes                          1
# Symptom_Muscle_spasms                        1
# Symptom_Muscle_aches                         1
# dtype: int64

# %%
shared = shared.transpose()

# %% [markdown]
# ##### Here we plot the co-occurence distributiuons for the symptoms with the lowest and highest mean co-occurence count respectively:

# %%
plt.subplot(2,1,1)
shared['Symptom_Memory_short'].hist()
plt.ylabel('frequency')
# plt.xlabel('number of co-occuring symptoms')
plt.title('Symptom_Memory_short');
plt.subplot(2,1,2)
shared['Symptom_Hallucinations_tactile'].hist()
plt.ylabel('frequency')
plt.xlabel('number of co-occuring symptoms')
plt.title('Symptom_Hallucinations_tactile');
plt.tight_layout()

# %% [markdown]
# #### TODO: Convert these to row-wise symtom sharing (i.e. extract lists of shared features)

# %%
df.to_numpy().nonzero()
# Out:
# (array([   0,    0,    0, ..., 6034, 6034, 6034]),
#  array([  0,   5,   7, ..., 132, 162, 163]))

# %% [markdown]
# ### Finally, what symptoms do the 3% of people without fatigue have?

# %%
no_fatigue = df[df.Symptom_Fatigue.isna()]

# %%
no_fatigue = no_fatigue.sum().sort_values(ascending=False)

# %%
no_fatigue = pd.DataFrame(no_fatigue, columns=['count'])

# %%
no_fatigue['frequency'] = no_fatigue['count'] / df.Symptom_Fatigue.isna().sum()

# %%
main_count = pd.DataFrame(df.sum(), columns=['count (whole dataset)'])
no_fatigue = no_fatigue.join(other=main_count)
no_fatigue['frequency (whole dataset)'] = no_fatigue['count (whole dataset)'] / len(df)

# %%
no_fatigue.head(20)
# Out:
#                                          count  frequency  \
# Symptom_Memory_short                     120.0   0.967742
# Symptom_PEM                               55.0   0.443548
# Symptom_Tightness_of_chest                50.0   0.403226
# Symptom_Heart_palpitations                49.0   0.395161
# Symptom_Shortness_of_breath               49.0   0.395161
# Symptom_Insomnia                          45.0   0.362903
# Symptom_Diarrhea                          44.0   0.354839
# Symptom_Tachycardia                       42.0   0.338710
# Symptom_Dry_cough                         41.0   0.330645
# Symptom_Pain_burning_chest                40.0   0.322581
# Symptom_Loss_of_smell                     39.0   0.314516
# Symptom_Sensations_tingling_prickling     39.0   0.314516
# Symptom_Tremors                           39.0   0.314516
# Symptom_Sensations_skin_burning_no_rash   38.0   0.306452
# Symptom_Gasping_air_normal_oxygen         37.0   0.298387
# Symptom_Loss_of_appetite                  37.0   0.298387
# Symptom_Sore_throat                       37.0   0.298387
# Symptom_Vibrating_sensations              35.0   0.282258
# Symptom_Loss_of_taste                     32.0   0.258065
# Symptom_Dizziness_vertigo                 32.0   0.258065
#
#                                          count (whole dataset)  \
# Symptom_Memory_short                                    5578.0
# Symptom_PEM                                             5333.0
# Symptom_Tightness_of_chest                              4105.0
# Symptom_Heart_palpitations                              3961.0
# Symptom_Shortness_of_breath                             4447.0
# Symptom_Insomnia                                        4183.0
# Symptom_Diarrhea                                        3326.0
# Symptom_Tachycardia                                     3573.0
# Symptom_Dry_cough                                       3839.0
# Symptom_Pain_burning_chest                              2854.0
# Symptom_Loss_of_smell                                   2365.0
# Symptom_Sensations_tingling_prickling                   2902.0
# Symptom_Tremors                                         2434.0
# Symptom_Sensations_skin_burning_no_rash                 2760.0
# Symptom_Gasping_air_normal_oxygen                       3416.0
# Symptom_Loss_of_appetite                                3010.0
# Symptom_Sore_throat                                     3329.0
# Symptom_Vibrating_sensations                            2472.0
# Symptom_Loss_of_taste                                   2160.0
# Symptom_Dizziness_vertigo                               4058.0
#
#                                          frequency (whole dataset)
# Symptom_Memory_short                                      0.924275
# Symptom_PEM                                               0.883679
# Symptom_Tightness_of_chest                                0.680199
# Symptom_Heart_palpitations                                0.656338
# Symptom_Shortness_of_breath                               0.736868
# Symptom_Insomnia                                          0.693123
# Symptom_Diarrhea                                          0.551118
# Symptom_Tachycardia                                       0.592046
# Symptom_Dry_cough                                         0.636123
# Symptom_Pain_burning_chest                                0.472908
# Symptom_Loss_of_smell                                     0.391881
# Symptom_Sensations_tingling_prickling                     0.480862
# Symptom_Tremors                                           0.403314
# Symptom_Sensations_skin_burning_no_rash                   0.457332
# Symptom_Gasping_air_normal_oxygen                         0.566031
# Symptom_Loss_of_appetite                                  0.498757
# Symptom_Sore_throat                                       0.551616
# Symptom_Vibrating_sensations                              0.409611
# Symptom_Loss_of_taste                                     0.357912
# Symptom_Dizziness_vertigo                                 0.672411

# %%
no_fatigue.tail(20)
# Out:
#                                                     count  frequency  \
# Symptom_Restless_leg                                  4.0   0.032258
# Symptom_Reproductive_abnormally_heavy_periods_c...    4.0   0.032258
# Symptom_Slurring_words                                4.0   0.032258
# Symptom_Dermatographia                                4.0   0.032258
# Symptom_New_anaphylaxis                               3.0   0.024194
# Symptom_Speech_changes_to_secondary_languages         3.0   0.024194
# Symptom_Speech_other                                  3.0   0.024194
# Symptom_SkinAllergy_shingles                          3.0   0.024194
# Symptom_Sensations_facial_pressure_right              3.0   0.024194
# Symptom_SkinAllergy_other_itchy                       3.0   0.024194
# Symptom_Cognitive_Functioning_agnosia                 3.0   0.024194
# Symptom_Eye_Vision_double_vision                      2.0   0.016129
# Symptom_Reproductive_early_menopause                  1.0   0.008065
# Symptom_Hallucinations_other                          1.0   0.008065
# Symptom_Hallucinations_tactile                        1.0   0.008065
# Symptom_Reproductive_postmenopausal_bleeding          0.0   0.000000
# Symptom_Eye_Vision_tunnel_vision                      0.0   0.000000
# Symptom_Eye_Vision_loss_of_vision                     0.0   0.000000
# Symptom_Fatigue                                       0.0   0.000000
# Symptom_Heightened_taste                              0.0   0.000000
#
#                                                     count (whole dataset)  \
# Symptom_Restless_leg                                               1145.0
# Symptom_Reproductive_abnormally_heavy_periods_c...                  576.0
# Symptom_Slurring_words                                             1007.0
# Symptom_Dermatographia                                              485.0
# Symptom_New_anaphylaxis                                             259.0
# Symptom_Speech_changes_to_secondary_languages                       336.0
# Symptom_Speech_other                                                260.0
# Symptom_SkinAllergy_shingles                                        155.0
# Symptom_Sensations_facial_pressure_right                            410.0
# Symptom_SkinAllergy_other_itchy                                     346.0
# Symptom_Cognitive_Functioning_agnosia                               653.0
# Symptom_Eye_Vision_double_vision                                    480.0
# Symptom_Reproductive_early_menopause                                 84.0
# Symptom_Hallucinations_other                                        141.0
# Symptom_Hallucinations_tactile                                      203.0
# Symptom_Reproductive_postmenopausal_bleeding                         97.0
# Symptom_Eye_Vision_tunnel_vision                                    231.0
# Symptom_Eye_Vision_loss_of_vision                                    67.0
# Symptom_Fatigue                                                    5911.0
# Symptom_Heightened_taste                                            186.0
#
#                                                     frequency (whole dataset)
# Symptom_Restless_leg                                                 0.189727
# Symptom_Reproductive_abnormally_heavy_periods_c...                   0.095443
# Symptom_Slurring_words                                               0.166860
# Symptom_Dermatographia                                               0.080365
# Symptom_New_anaphylaxis                                              0.042916
# Symptom_Speech_changes_to_secondary_languages                        0.055675
# Symptom_Speech_other                                                 0.043082
# Symptom_SkinAllergy_shingles                                         0.025684
# Symptom_Sensations_facial_pressure_right                             0.067937
# Symptom_SkinAllergy_other_itchy                                      0.057332
# Symptom_Cognitive_Functioning_agnosia                                0.108202
# Symptom_Eye_Vision_double_vision                                     0.079536
# Symptom_Reproductive_early_menopause                                 0.013919
# Symptom_Hallucinations_other                                         0.023364
# Symptom_Hallucinations_tactile                                       0.033637
# Symptom_Reproductive_postmenopausal_bleeding                         0.016073
# Symptom_Eye_Vision_tunnel_vision                                     0.038277
# Symptom_Eye_Vision_loss_of_vision                                    0.011102
# Symptom_Fatigue                                                      0.979453
# Symptom_Heightened_taste                                             0.030820

# %% [markdown]
# #### Investigating Symptom_Memory_short occuring w/o any other features...

# %%
shared[shared['Symptom_Memory_short']==0].index
# Out:
# Index([3653, 4415, 4770, 5014, 5335], dtype='int64')

# %%
all_data = pd.read_csv('../data/cleaned_data_SYMPTOMS_9_13_23.csv', index_col=0)

# %%
check = all_data.iloc[shared[shared['Symptom_Memory_short']==0].index]

# %%
symptoms = [c for c in all_data.columns if 'Symptom' in c]
non_symptoms = [c for c in all_data.columns if 'Symptom' not in c]

# %%
check[non_symptoms]
# Out:
#               Demographics_Ancestry_Cleaned Demographics_Gender_Cleaned  \
# 6946                                  White                       Woman
# 9633                                  White                         Man
# 10851  Asian, South Asian, South East Asian                         NaN
# 11496                                   NaN                       Woman
# 12396                                 Black                       Woman
#
#        Demographics_Trans_Cleaned Demographics_Age_Cleaned  Flag_MECFS  \
# 6946                          0.0                    40-49         0.0
# 9633                          0.0                    50-59         0.0
# 10851                         0.0                    70-79         0.0
# 11496                         0.0                    30-39         0.0
# 12396                         0.0                    40-49         0.0
#
#                 Flag_POTS  Flag_MCAS   FAS             FAS_cat  \
# 6946   No, no tachycardia        0.0   9.0  Minimal/No Fatigue
# 9633   No, no tachycardia        0.0   9.0  Minimal/No Fatigue
# 10851  No, no tachycardia        0.0   9.0  Minimal/No Fatigue
# 11496  No, no tachycardia        0.0  11.0  Minimal/No Fatigue
# 12396  No, no tachycardia        0.0   9.0  Minimal/No Fatigue
#
#        Physical_PEM_Severity  Cognitive_PEM_Severity        HasPeriods
# 6946                     NaN                     NaN               Yes
# 9633                     NaN                     NaN               NaN
# 10851                    NaN                     NaN  No, other reason
# 11496                    NaN                     NaN               NaN
# 12396                    NaN                     NaN               Yes

# %%
check[symptoms].sum(axis=1)
# Out:
# 6946     1.0
# 9633     1.0
# 10851    1.0
# 11496    1.0
# 12396    1.0
# dtype: float64
